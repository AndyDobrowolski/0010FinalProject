# %% [markdown]
# ### Toxics Release Inventory

# %% [markdown]
# Most enviromentally firendly neighborhood.

# %%
# imports
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# show the first ten rows
tri = pd.read_csv('Datasets\TRI_facilities.csv')
tri.head(10)
# Out:
#                 ID                                      FACILITY_NAME  \
# 0  15122SGKYW890NO                    KEYWELL CORP VAC AIR ALLOYS DIV
# 1  15205LLMRC4590C                            ALL AMERICAN GOURMET CO
# 2  15065HCKTTFEDER                            HARSCO METALS - NATRONA
# 3  15024CHSWCPITTS                               CHESWICK POWER PLANT
# 4  15025GRDNN1000G          GUARDIAN INDUSTRIES CORP - FLOREFFE PLANT
# 5  15203SMLBN88SOU                                         BINGHAM CO
# 6  15238WSTNG200BE  EMERSON PROCESS MANAGEMENT POWER & WATER SOLUT...
# 7  15120WSTHMWESTS                          WHEMCO-STEEL CASTINGS INC
# 8  15212HNZSX1062P                               BAY VALLEY FOODS LLC
# 9  15024LLGHN1105P                                ALLEGHENY LABEL INC
#
#                                   STREET_ADDRESS        CITY_NAME COUNTY_NAME  \
# 0                                   890 NOBLE DR     WEST MIFFLIN   ALLEGHENY
# ...

# %%
# pick out the city of Pittsburgh
query_mask = tri['CITY_NAME'] == "PITTSBURGH"
query_mask.head(10)
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7    False
# 8     True
# 9    False
# Name: CITY_NAME, dtype: bool

# %%
# show the TRI in Pittsburgh
pittsburgh_tri = tri[query_mask]
pittsburgh_tri.head()
# Out:
#                  ID                                      FACILITY_NAME  \
# 1   15205LLMRC4590C                            ALL AMERICAN GOURMET CO
# 5   15203SMLBN88SOU                                         BINGHAM CO
# 6   15238WSTNG200BE  EMERSON PROCESS MANAGEMENT POWER & WATER SOLUT...
# 8   15212HNZSX1062P                               BAY VALLEY FOODS LLC
# 10  15202HKNCN2150R                     BALL METAL FOOD CONTAINER CORP
#
#            STREET_ADDRESS   CITY_NAME COUNTY_NAME  STATE_COUNTY_FIPS_CODE  \
# 1   4590 CAMPBELLS RUN RD  PITTSBURGH   ALLEGHENY                   42003
# 5            88 S 13TH ST  PITTSBURGH   ALLEGHENY                   42003
# 6          200 BETA DRIVE  PITTSBURGH   ALLEGHENY                   42003
# 8          1080 RIVER AVE  PITTSBURGH   ALLEGHENY                   42003
# 10        2150 ROSWELL DR  PITTSBURGH   ALLEGHENY                   42003
#
#    STATE_ABBR  ZIP_CODE  REGION  FAC_CLOSED_IND  ... PREF_SOURCE_SCALE  \
# ...
