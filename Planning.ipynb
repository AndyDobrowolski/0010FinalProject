# %% [markdown]
# This file is mostly for the planning phase.
# It will allow us to test things out with some of the data before we add it onto a main file.
# This file will most likely either be modified or deleted before the final submission.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
trees       = pd.read_csv('Datasets\Trees.csv'          )
containers  = pd.read_csv('Datasets\TrashContainers.csv')

# %%
trees["neighborhood"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
containers["neighborhood"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>
