# %% [markdown]
# ### Waste Recovery Location

# %% [markdown]
# Most enviromentally firendly neighborhood.

# %%
#imports
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
waste_recovery = pd.read_csv('Datasets\WasteRecoveryLocations.csv')
waste_recovery.head(10)
# Out:
#            id                                name  address_number  \
# 0  1961537237           ABC - EX Transfer Station          1010.0
# 1  1712687323   Advance Auto Parts - Babcock Blvd          1445.0
# 2  2029078673   Advance Auto Parts - East Liberty          5905.0
# 3  1877381706           Advance Auto Parts - Etna           475.0
# 4  1160745337  Allegheny County Health Department          3901.0
# 5   758154727                 Appliance Warehouse           504.0
# 6   701945774  Batteries Plus Bulbs - North Hills          4808.0
# 7  1693588898     Batteries Plus Bulbs - Robinson           401.0
# 8   628800794                Best Buy - Homestead             NaN
# 9  1091895125              Best Buy - North Hills             NaN
#
#          street               city  \
# 0      McKee St          Stowe Twp
# 1  Babcock Blvd         Shaler Twp
# 2    Station St         Pittsburgh
# 3     Butler St               Etna
# 4      Penn Ave         Pittsburgh
# ...
